# %% [markdown]
# ## EARLY ALZHEIMER'S DETECTION USING PYCARET LIBRARY

# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('data/oasis_longitudinal.csv')
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
# use first visit data only because of the analysis we're doing
df = df.loc[df['Visit']==1] 

 # reset index after filtering first visit data
df = df.reset_index(drop=True)

# M/F column
df['M/F'] = df['M/F'].replace(['F','M'], [0,1]) 

# Target variable
df['Group'] = df['Group'].replace(['Converted'], ['Demented'])
df['Group'] = df['Group'].replace(['Demented', 'Nondemented'], [1,0]) 

# Drop unnecessary columns
df = df.drop(['MRI ID', 'Visit', 'Hand'], axis=1)

# %%
# Dropped the 8 rows with missing values in the column, SES
df = df.dropna(axis=0, how='any')
pd.isnull(df).sum()
# Out:
# Subject ID    0
# Group         0
# MR Delay      0
# M/F           0
# Age           0
# EDUC          0
# SES           0
# MMSE          0
# CDR           0
# eTIV          0
# nWBV          0
# ASF           0
# dtype: int64

# %%
df = df.drop("Subject ID", axis=1)

# %%
df.head()
# Out:
#    Group  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      0         0    1   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 2      0         0    0   88    18  3.0  28.0  0.0  1215  0.710  1.444
# 3      0         0    1   80    12  4.0  28.0  0.0  1689  0.712  1.039
# 5      0         0    0   93    14  2.0  30.0  0.0  1272  0.698  1.380
# 6      1         0    1   68    12  2.0  27.0  0.5  1457  0.806  1.205

# %%
df.dtypes
# Out:
# Group         int64
# MR Delay      int64
# M/F           int64
# Age           int64
# EDUC          int64
# SES         float64
# MMSE        float64
# CDR         float64
# eTIV          int64
# nWBV        float64
# ASF         float64
# dtype: object

# %% [markdown]
# ## Train and Evlauate model

# %%
experiment = setup(df, target="Group",train_size = 0.8,fold_shuffle=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf115_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf115_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf115_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_bf115_row0_col1" class="data row0 col1" >8475</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf115_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bf115_row1_col1" class="data row1 col1" >Group</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf115_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_bf115_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bf115_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_bf115_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bf115_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_bf115_row4_col1" class="data row4 col1" >(142, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bf115_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_bf115_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bf115_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_bf115_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bf115_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_bf115_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bf115_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_bf115_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bf115_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_bf115_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bf115_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_bf115_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bf115_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_bf115_row11_col1" class="data row11 col1" >(113, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bf115_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_bf115_row12_col1" class="data row12 col1" >(29, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bf115_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_bf115_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bf115_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_bf115_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bf115_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_bf115_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bf115_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_bf115_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bf115_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_bf115_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bf115_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_bf115_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_bf115_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_bf115_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_bf115_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_bf115_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_bf115_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_bf115_row21_col1" class="data row21 col1" >4fca</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_bf115_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_bf115_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_bf115_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_bf115_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_bf115_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_bf115_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_bf115_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_bf115_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_bf115_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_bf115_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_bf115_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_bf115_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_bf115_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_bf115_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_bf115_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_bf115_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_bf115_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_bf115_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bf115_level0_row31" class="row_heading l
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Temp/ipykernel_6888/3493813421.py in <module>
# ----> 1 experiment = setup(df, target="Group",train_size = 0.8,fold_shuffle=True)
#
# D:\Anaconda\lib\site-packages\pycaret\classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     578         log_plots = ["auc", "confusion_matrix", "feature"]
#     579
# --> 580     return pycaret.internal.tabular.setup(
#     581         ml_usecase="classification",
#     582         available_plots=available_plots,
#
# D:\Anaconda\lib\site-packages\pycaret\internal\tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1743     logger.info(f"display_container: {len(display_container)}")
#    1744
# -> 1745     logger.info(str(prep_pipe))
#    1746     logger.info("setup() succesfully completed......................................")
#    1747
#
# D:\Anaconda\lib\site-packages\sklearn\base.py in __repr__(self, N_CHAR_MAX)
#     277         )
#     278
# --> 279         repr_ = pp.pformat(self)
#     280
#     281         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# D:\Anaconda\lib\pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# D:\Anaconda\lib\pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# D:\Anaconda\lib\pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# D:\Anaconda\lib\site-packages\sklearn\utils\_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# D:\Anaconda\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     450                 k, context, maxlevels, level, changed_only=changed_only
#     451             )
# --> 452             vrepr, vreadable, vrecur = saferepr(
#     453                 v, context, maxlevels, level, changed_only=changed_only
#     454             )
#
# D:\Anaconda\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# D:\Anaconda\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# D:\Anaconda\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     440             params = _changed_params(object)
#     441         else:
# --> 442             params = object.get_params(deep=False)
#     443         components = []
#     444         append = components.append
#
# D:\Anaconda\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     209         out = dict()
#     210         for key in self._get_param_names():
# --> 211             value = getattr(self, key)
#     212             if deep and hasattr(value, "get_params") and not isinstance(value, type):
#     213                 deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_c08f0_ th {
#   text-align: left;
# }
# #T_c08f0_row0_col0, #T_c08f0_row0_col2, #T_c08f0_row0_col3, #T_c08f0_row1_col0, #T_c08f0_row1_col1, #T_c08f0_row1_col2, #T_c08f0_row1_col3, #T_c08f0_row1_col4, #T_c08f0_row1_col5, #T_c08f0_row1_col6, #T_c08f0_row1_col7, #T_c08f0_row2_col0, #T_c08f0_row2_col1, #T_c08f0_row2_col2, #T_c08f0_row2_col3, #T_c08f0_row2_col4, #T_c08f0_row2_col5, #T_c08f0_row2_col6, #T_c08f0_row2_col7, #T_c08f0_row3_col0, #T_c08f0_row3_col1, #T_c08f0_row3_col2, #T_c08f0_row3_col3, #T_c08f0_row3_col4, #T_c08f0_row3_col5, #T_c08f0_row3_col6, #T_c08f0_row3_col7, #T_c08f0_row4_col0, #T_c08f0_row4_col1, #T_c08f0_row4_col3, #T_c08f0_row4_col4, #T_c08f0_row4_col5, #T_c08f0_row4_col6, #T_c08f0_row4_col7, #T_c08f0_row5_col0, #T_c08f0_row5_col1, #T_c08f0_row5_col2, #T_c08f0_row5_col3, #T_c08f0_row5_col4, #T_c08f0_row5_col5, #T_c08f0_row5_col6, #T_c08f0_row5_col7, #T_c08f0_row6_col0, #T_c08f0_row6_col1, #T_c08f0_row6_col2, #T_c08f0_row6_col3, #T_c08f0_row6_col4, #T_c08f0_row6_col5, #T_c08f0_row6_col6, #T_c08f0_row6_col7, #T_c08f0_row7_col0, #T_c08f0_row7_col1, #T_c08f0_row7_col2, #T_c08f0_row7_col3, #T_c08f0_row7_col4, #T_c08f0_row7_col5, #T_c08f0_row7_col6, #T_c08f0_row7_col7, #T_c08f0_row8_col0, #T_c08f0_row8_col1, #T_c08f0_row8_col2, #T_c08f0_row8_col3, #T_c08f0_row8_col4, #T_c08f0_row8_col5, #T_c08f0_row8_col6, #T_c08f0_row8_col7, #T_c08f0_row9_col0, #T_c08f0_row9_col1, #T_c08f0_row9_col2, #T_c08f0_row9_col4, #T_c08f0_row9_col5, #T_c08f0_row9_col6, #T_c08f0_row9_col7, #T_c08f0_row10_col0, #T_c08f0_row10_col1, #T_c08f0_row10_col2, #T_c08f0_row10_col3, #T_c08f0_row10_col4, #T_c08f0_row10_col5, #T_c08f0_row10_col6, #T_c08f0_row10_col7, #T_c08f0_row11_col0, #T_c08f0_row11_col1, #T_c08f0_row11_col2, #T_c08f0_row11_col3, #T_c08f0_row11_col4, #T_c08f0_row11_col5, #T_c08f0_row11_col6, #T_c08f0_row11_col7, #T_c08f0_row12_col0, #T_c08f0_row12_col1, #T_c08f0_row12_col2, #T_c08f0_row12_col3, #T_c08f0_row12_col4, #T_c08f0_row12_col5, #T_c08f0_row12_col6, #T_c08f0_row12_col7, #T_c08f0_row13_col0, #T_c08f0_row13_col1, #T_c08f0_row13_col2, #T_c08f0_row13_col3, #T_c08f0_row13_col4, #T_c08f0_row13_col5, #T_c08f0_row13_col6, #T_c08f0_row13_col7, #T_c08f0_row14_col0, #T_c08f0_row14_col1, #T_c08f0_row14_col2, #T_c08f0_row14_col3, #T_c08f0_row14_col4, #T_c08f0_row14_col5, #T_c08f0_row14_col6, #T_c08f0_row14_col7 {
#   text-align: left;
# }
# #T_c08f0_row0_col1, #T_c08f0_row0_col4, #T_c08f0_row0_col5, #T_c08f0_row0_col6, #T_c08f0_row0_col7, #T_c08f0_row4_col2, #T_c08f0_row9_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c08f0_row0_col8, #T_c08f0_row1_col8, #T_c08f0_row2_col8, #T_c08f0_row3_col8, #T_c08f0_row4_col8, #T_c08f0_row5_col8, #T_c08f0_row6_col8, #T_c08f0_row7_col8, #T_c08f0_row8_col8, #T_c08f0_row9_col8, #T_c08f0_row10_col8, #T_c08f0_row12_col8, #T_c08f0_row13_col8, #T_c08f0_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c08f0_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c08f0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c08f0_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_c08f0_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_c08f0_row0_col1" class="data row0 col1" >0.9023</td>
#       <td id="T_c08f0_row0_col2" class="data row0 col2" >0.9072</td>
#       <td id="T_c08f0_row0_col3" class="data row0 col3" >0.8133</td>
#       <td id="T_c08f0_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_c08f0_row0_col5" class="data row0 col5" >0.8943</td>
#       <td id="T_c08f0_row0_col6" class="data row0 col6" >0.8063</td>
#       <td id="T_c08f0_row0_col7" class="data row0 col7" >0.8244</td>
#       <td id="T_c08f0_row0_col8" class="data row0 col8" >0.7130</td>
#     </tr>
#     <tr>
#       <th id="T_c08f0_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_c08f0_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_c08f0_row1_col1" class="data row1 col1" >0.8848</td>
#       <td id="T_c08f0_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_c08f0_row1_col3" class="data row1 col3" >0.7967</td>
#       <td id="T_c08f0_row1_col4" class="data row1 col4" >0.9833</td>
#       <td id="T_c08f0_row1_col5" class="data row1 col5" >0.8759</td>
#       <td id="T_c08f0_row1_col6" class="data row1 col6" >0.7710</td>
#       <td id="T_c08f0_row1_col7" class="data row1 col7" >0.7906</td>
#       <td id="T_c08f0_row1_col8" class="data row1 col8" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_c08f0_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_c08f0_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_c08f0_row2_col1" class="data row2 col1" >0.8841</td>
#       <td id="T_c08f0_row2_col2" class="data row2 col2" >0.9022</td>
#       <td id="T_c08f0_row2_col3" class="data row2 col3" >0.8300</td>
#       <td id="T_c08f0_row2_col4" class="data row2 col4" >0.9467</td>
#       <td id="T_c08f0_row2_col5" class="data row2 col5" >0.8812</td>
#       <td id="T_c08f0_row2_col6" class="data row2 col6" >0.7685</td>
#       <td id="T_c08f0_row2_col7" class="data row2 col7" >0.7792</td>
#       <td id="T_c08f0_row2_col8" class="data row2 col8" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_c08f0_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_c08f0_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_c08f0_row3_col1" class="data row3 col1" >0.8765</td>
#       <td id="T_c08f0_row3_col2" class="data row3 col2" >0.8931</td>
#       <td id="T_c08f0_row3_col3" class="data row3 col3" >0.8133</td>
#       <td id="T_c08f0_row3_col4" class="data row3 col4" >0.9467</td>
#       <td id="T_c08f0_row3_col5" class="data row3 col5" >0.8701</td>
#       <td id="T_c08f0_row3_col6" class="data row3 col6" >0.7537</td>
#       <td id="T_c08f0_row3_col7" class="data row3 col7" >0.7670</td>
#       <td id="T_c08f0_row3_col8" class="data row3 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_c08f0_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_c08f0_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_c08f0_row4_col1" class="data row4 col1" >0.8667</td>
#       <td id="T_c08f0_row4_col2" class="data row4 col2" >0.9239</td>
#       <td id="T_c08f0_row4_col3" class="data row4 col3" >0.7800</td>
#       <td id="T_c08f0_row4_col4" class="data row4 col4" >0.9667</td>
#       <td id="T_c08f0_row4_col5" class="data row4 col5" >0.8592</td>
#       <td id="T_c08f0_row4_col6" class="data row4 col6" >0.7343</td>
#       <td id="T_c08f0_row4_col7" class="data row4 col7" >0.7539</td>
#       <td id="T_c08f0_row4_col8" class="data row4 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_c08f0_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_c08f0_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_c08f0_row5_col1" class="data row5 col1" >0.8576</td>
#       <td id="T_c08f0_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_c08f0_row5_col3" class="data row5 col3" >0.8133</td>
#       <td id="T_c08f0_row5_col4" class="data row5 col4" >0.9148</td>
#       <td id="T_c08f0_row5_col5" class="data row5 col5" >0.8566</td>
#       <td id="T_c08f0_row5_col6" class="data row5 col6" >0.7151</td>
#       <td id="T_c08f0_row5_col7" class="data row5 col7" >0.7262</td>
#       <td id="T_c08f0_row5_col8" class="data row5 col8"
